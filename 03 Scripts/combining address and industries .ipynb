# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
pip install geopy
# Out:
# ...
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 982.9 kB/s eta 0:00:00 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Folder location string
path = r'C:\Users\nurgul\Linkedin'

# %%
# Importing cleaned dataset
df = pd.read_csv('jobs_posts_clean_latest1.csv', index_col=False)

# %%
df.head()
# Out:
#        job_id  company_id                                        title  \
# 0  3757937095      437225  Principal Cloud Security Architect (Remote)
# 1  3757935381    19181907             Insights Analyst - Auto Industry
# 2  3757935381    19181907             Insights Analyst - Auto Industry
# 3  3757935381    19181907             Insights Analyst - Auto Industry
# 4  3757935001    73013724                                Sales Manager
#
#    max_salary  min_salary  work_type           location    applies  \
# 0    275834.0    205956.0  Full-time      United States  31.256076
# 1     64000.0     58000.0  Full-time      United States  17.361502
# 2     64000.0     58000.0  Full-time      United States  24.096085
# 3     64000.0     58000.0  Full-time      United States  31.256076
# 4    350000.0    125000.0  Full-time  Coeur d'Alene, ID  18.329151
#
#         views  experience_level          listed_time  approx_salary  \
# ...

# %%
location_counts = df['location'].value_counts()
print(location_counts)
# Out:
# location
# United States                      1151
# New York, NY                        679
# Los Angeles, CA                     288
# New York City Metropolitan Area     267
# Seattle, WA                         256
#                                    ...
# Baldwinsville, NY                     1
# Byron, IL                             1
# El Monte, CA                          1
# Alabaster, AL                         1
# Rockingham, NC                        1
# Name: count, Length: 1826, dtype: int64

# %%
df = df[df['location'] != 'United States']

# %%
df.shape
# Out:
# (13530, 20)

# %%
 #Finding Missing Values
df.isnull().sum()
# Out:
# job_id              0
# company_id          0
# title               0
# max_salary          0
# min_salary          0
# work_type           0
# location            0
# applies             0
# views               0
# experience_level    0
# listed_time         0
# approx_salary       0
# name                0
# company_size        0
# state               0
# country             0
# zip_code            7
# skill_abr           0
# salary_category     3
# applies_category    0
# dtype: int64

# %%
df.dropna(subset=['salary_category',''], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/b1/dcgm49cs1dx0p3lkf95fklvr0000gp/T/ipykernel_22981/2079019675.py in ?()
# ----> 1 df.dropna(subset=['salary_category',''], inplace=True)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6653             ax = self._get_axis(agg_axis)
#    6654             indices = ax.get_indexer_for(subset)
#    6655             check = indices == -1
#    6656             if check.any():
# -> 6657                 raise KeyError(np.array(subset)[check].tolist())
#    6658             agg_obj = self.take(indices, axis=agg_axis)
#    6659
#    6660         if thresh is not lib.no_default:
#
# KeyError: ['']

# %%
 #Finding Missing Values
df.isnull().sum()
# Out:
# job_id              0
# company_id          0
# title               0
# max_salary          0
# min_salary          0
# work_type           0
# location            0
# applies             0
# views               0
# experience_level    0
# listed_time         0
# approx_salary       0
# name                0
# company_size        0
# state               0
# country             0
# zip_code            0
# skill_abr           0
# salary_category     0
# applies_category    0
# dtype: int64

# %%
# Importing cleaned dataset
df_ind = pd.read_csv('company_industries.csv', index_col=False)

# %%
merged_df = pd.merge(df, df_ind, on='company_id', how='inner')

# %%
merged_df.isnull().sum()
# Out:
# job_id              0
# company_id          0
# title               0
# max_salary          0
# min_salary          0
# work_type           0
# location            0
# applies             0
# views               0
# experience_level    0
# listed_time         0
# approx_salary       0
# name                0
# company_size        0
# state               0
# country             0
# zip_code            0
# skill_abr           0
# salary_category     0
# applies_category    0
# industry            0
# dtype: int64

# %%
merged_df.head()
# Out:
#        job_id  company_id              title  max_salary  min_salary  \
# 0  3757935001    73013724      Sales Manager    350000.0    125000.0
# 1  3757935001    73013724      Sales Manager    350000.0    125000.0
# 2  3757934347    10515052    Body Technician        30.0        20.0
# 3  3757934347    10515052    Body Technician        30.0        20.0
# 4  3757934319    18391435  Controls Engineer    150000.0    121000.0
#
#    work_type           location    applies      views  experience_level  ...  \
# 0  Full-time  Coeur d'Alene, ID  18.329151  66.426309  Mid-Senior level  ...
# 1  Full-time  Coeur d'Alene, ID  17.496124  61.180585  Mid-Senior level  ...
# 2  Full-time       Waukesha, WI  26.281996  80.649722       Entry level  ...
# 3  Full-time       Waukesha, WI  31.256076  96.929148       Entry level  ...
# 4  Full-time        Orlando, FL   1.000000   5.000000  Mid-Senior level  ...
#
#   approx_salary                      name company_size     state country  \
# ...

# %%
merged_df['industry'] = merged_df['industry'].str.replace('&', 'and', case=False)

# %%
industry_counts = merged_df['industry'].value_counts()
print(industry_counts)
# Out:
# industry
# Staffing and Recruiting                6426
# IT Services and IT Consulting          1079
# Information Technology and Services     966
# Software Development                    694
# Computer Software                       684
#                                        ...
# Package/Freight Delivery                  1
# Musicians                                 1
# Sports                                    1
# Civic and Social Organization             1
# Photography                               1
# Name: count, Length: 178, dtype: int64

# %%
# Assuming your dataframe is named df
unique_industries = merged_df['industry'].unique()

# Print or view the unique industries
print(unique_industries)
# Out:
# ['Financial Services' 'Motor Vehicle Manufacturing'
#  'Staffing and Recruiting' 'Retail Office Equipment'
#  'Food and Beverage Manufacturing' 'Wholesale' 'Hospitals and Health Care'
#  'Travel Arrangements' 'Biotechnology Research' 'Hospital and Health Care'
#  'Entertainment' 'Entertainment Providers' 'Food Production'
#  'IT Services and IT Consulting' 'Retail' 'Telecommunications'
#  'Truck Transportation' 'Defense and Space Manufacturing' 'Law Practice'
#  'Manufacturing' 'Computer Hardware Manufacturing'
#  'Furniture and Home Furnishings Manufacturing'
#  'Retail Apparel and Fashion' 'Construction' 'Apparel and Fashion'
#  'Hospitality' 'Software Development' 'Real Estate'
#  'Non-profit Organizations' 'Banking' 'Insurance' 'Mining'
#  'Education Administration Programs' 'Spectator Sports'
#  'Pharmaceutical Manufacturing' 'Government Administration' 'Chemicals'
#  'Chemical Manufacturing' 'Information Technology and Services'
# ...

# %%
import pandas as pd

# Assuming your dataframe is named df
merged_df['industry'].replace({'Hospital and Health Care': 'Hospitals and Health Care'}, inplace=True)

# Print or view the unique industries after replacement
unique_industries = merged_df['industry'].unique()
print(unique_industries)
# Out:
# ['Financial Services' 'Motor Vehicle Manufacturing'
#  'Staffing and Recruiting' 'Retail Office Equipment'
#  'Food and Beverage Manufacturing' 'Wholesale' 'Hospitals and Health Care'
#  'Travel Arrangements' 'Biotechnology Research' 'Entertainment'
#  'Entertainment Providers' 'Food Production'
#  'IT Services and IT Consulting' 'Retail' 'Telecommunications'
#  'Truck Transportation' 'Defense and Space Manufacturing' 'Law Practice'
#  'Manufacturing' 'Computer Hardware Manufacturing'
#  'Furniture and Home Furnishings Manufacturing'
#  'Retail Apparel and Fashion' 'Construction' 'Apparel and Fashion'
#  'Hospitality' 'Software Development' 'Real Estate'
#  'Non-profit Organizations' 'Banking' 'Insurance' 'Mining'
#  'Education Administration Programs' 'Spectator Sports'
#  'Pharmaceutical Manufacturing' 'Government Administration' 'Chemicals'
#  'Chemical Manufacturing' 'Information Technology and Services'
#  'Mental Health Care' 'Restaurants' 'Research Services' 'Automotive'
# ...

# %%
merged_df.shape
# Out:
# (19435, 21)

# %%
# Exporting dataframe 
merged_df.to_csv('jobs_posts_clean_withInd.csv', index=False)
